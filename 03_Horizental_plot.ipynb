# %% [markdown]
# # Horizental Plot in Pyhton

# %%
#import libraries
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt
# load dataset
kashti=sns.load_dataset("titanic")
kashti
# change size of figure
# plt.figure(figsize=(4,2))
# #draw a bar plot
sns.barplot(x="fare", y="class", hue="sex", data=kashti, estimator=median)
plt.show()

# %%
#import libraries
import seaborn as sns
from numpy import median
import matplotlib.pyplot as plt
# load dataset
kashti=sns.load_dataset("titanic")
kashti
# change size of figure
# plt.figure(figsize=(4,2))
# #draw a bar plot
sns.barplot(x="class", y="fare", data=kashti, linewidth=3,errcolor="0.2", edgecolor="0",facecolor=(0.1,0.2,0.3,0.4))
plt.show()
